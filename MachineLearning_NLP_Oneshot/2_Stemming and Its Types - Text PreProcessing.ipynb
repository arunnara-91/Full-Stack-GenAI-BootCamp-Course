# %% [markdown]
# Stemming
#
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
# Stemming is the process of reducing a word to its base or root form. it is used to reduce the number of unique words in a text data by converting different forms of a word to a common base form. for example, the words "running", "runner", and "ran" can be reduced to the base form "run". stemming is used in natural language processing tasks such as text classification, information retrieval, and sentiment analysis. it helps to improve the performance of these tasks by reducing the dimensionality of the text data and increasing the frequency of the base form of the word.   
# lemmatization is the process of reducing a word to its base or root form, but it also takes into account the context and the meaning of the word. it is used to reduce the number of unique words in a text data by converting different forms of a word to a common base form. for example, the words "running", "runner", and "ran" can be reduced to the base form "run". lemmatization is used in natural language processing tasks such as text classification, information retrieval, and sentiment analysis. it helps to improve the performance of these tasks by reducing the dimensionality of the text data and increasing the frequency of the base form of the word.
# lemmatization is more accurate than stemming because it considers the context and meaning of the word, while stemming only considers the surface form of the word.  
# example of stemming:
## classification problem:
## comments of product -> positive reviwew, negative review, neutral review
## review -> review, reviews, reviewing, reviewed -> review
## eating, eaten, eats -> eat
## running, runner, ran -> run
# Lemmatization example:
## classification problem
## comments of product -> positive reviwew, negative review, neutral review
## review -> review, reviews, reviewing, reviewed -> review
## eating, eaten, eats -> eat

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# Porter Stemmer

# %%
from nltk.stem import PorterStemmer
# PorterStemmer is a popular stemming algorithm that is used to reduce words to their base form. 
# it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form.

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word, "->", stemming.stem(word))
# Out:
# eating -> eat
# eats -> eat
# eaten -> eaten
# writing -> write
# writes -> write
# programming -> program
# programs -> program
# history -> histori
# finally -> final
# finalized -> final

# %%
stemming.stem("Congratulation")
# its not giving the correct output because it is a proper noun and it is not in the dictionary of the PorterStemmer. it is a limitation of the PorterStemmer. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form. it is a simple and efficient algorithm that is widely used in natural language processing tasks. it is based on a set of rules that are applied to the words to reduce them to their base form. it is a rule-based algorithm that uses a set of rules to reduce words to their base form.
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# it will be reduced to "sit" because the "ing" suffix is removed and the base form of the word is "sit".
# Out:
# 'sit'

# %% [markdown]
# RegexpStemmer class
#
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# Snowball Stemmer
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballsstemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('goes')
# Out:
# 'goe'
